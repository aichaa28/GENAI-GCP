# %%
import psycopg2
import torch
from sentence_transformers import SentenceTransformer
from langchain_google_vertexai import VertexAIEmbeddings
from langchain_google_cloud_sql_pg import PostgresVectorStore
from config import DB_HOST, DB_PORT, DB_NAME, DB_USER, DB_PASSWORD
from google.generativeai import configure, embed_content

# %%
# 1. Récupérer les données avec psycopg2 (classique)
conn = psycopg2.connect(
    dbname=DB_NAME,
    user=DB_USER,
    password=DB_PASSWORD,
    host=DB_HOST,
    port=DB_PORT
)
cursor = conn.cursor()
cursor.execute("SELECT id, content FROM ae_qa_table WHERE embedding IS NULL")
questions = cursor.fetchall()
cursor.close()
conn.close()

# %%
# Initialiser Hugging Face Embeddings (fallback)
hf_model = SentenceTransformer("sentence-transformers/all-mpnet-base-v2")

# %%
import pandas as pd
from langchain_google_vertexai import VertexAIEmbeddings
from langchain_google_cloud_sql_pg import PostgresEngine, PostgresVectorStore
from config import DB_NAME, DB_USER, DB_PASSWORD, PROJECT_ID, INSTANCE_NAME, REGION


engine = PostgresEngine.from_instance(
        project_id=PROJECT_ID,
        instance=INSTANCE_NAME,  # ex: "gen-ai-instance"
        region=REGION,           # ex: "europe-west1"
        database=DB_NAME,
        user=DB_USER,
        password=DB_PASSWORD
    )

# 3. Initialiser le Vector Store
embedding_model = VertexAIEmbeddings(model_name="textembedding-gecko", project=PROJECT_ID)
vector_store = PostgresVectorStore.create_sync(
        engine=engine,
        table_name="ae_qa_table",
        embedding_service=hf_model,
        id_column="langchain_id",
        content_column="content",
        embedding_column="embedding"
    )

# %%
questions
# Out:
# [(4, 'What is (are) Glaucoma ?'),
#  (15, 'How to prevent High Blood Pressure ?'),
#  (16, 'What are the symptoms of High Blood Pressure ?'),
#  (35, "What are the treatments for Paget's Disease of Bone ?"),
#  (43, 'What is (are) Alcohol Use and Older Adults ?'),
#  (53, 'What are the symptoms of Osteoarthritis ?'),
#  (74, 'What are the symptoms of Anxiety Disorders ?'),
#  (13862, 'What are the treatments for glycogen storage disease type III ?'),
#  (116, 'What is (are) Knee Replacement ?'),
#  (121, 'What is (are) Balance Problems ?'),
#  (141,
#   'what research (or clinical trials) is being done for Prostate Cancer ?'),
#  (140, 'What are the treatments for Prostate Cancer ?'),
#  (169, 'How to diagnose Osteoporosis ?'),
#  (438, 'what research (or clinical trials) is being done for Psoriasis ?'),
#  (444, 'What are the treatments for Psoriasis ?'),
#  (447, 'What is (are) Psoriasis ?'),
#  (222, 'What is (are) Hearing Loss ?'),
#  (223, 'How to prevent Hearing Loss ?'),
#  (224, 'What are the symptoms of Hearing Loss ?'),
#  (474, 'How to diagnose Peripheral Arterial Disease (P.A.D.) ?'),
#  (12350, 'Is congenital stromal corneal dystrophy inherited ?'),
#  (268, 'What are the treatments for Diabetic Retinopathy ?'),
#  (773, 'What is the outlook for Uterine Sarcoma ?'),
#  (300, 'Who is at risk for Breast Cancer? ?'),
#  (503, 'What are the treatments for Cataract ?'),
#  (307, 'What is (are) Breast Cancer ?'),
#  (306, 'What is (are) Breast Cancer ?'),
#  (348, "What is (are) Parkinson's Disease ?"),
#  (356, 'What are the symptoms of Leukemia ?'),
#  (374, 'What are the symptoms of Lung Cancer ?'),
#  (392, 'What are the treatments for Lung Cancer ?'),
#  (575, 'What is (are) Skin Cancer ?'),
#  (409, 'What is (are) Stroke ?'),
#  (588, 'What are the treatments for Surviving Cancer ?'),
#  (631, 'What is (are) Heart Failure ?'),
#  (614, 'What is (are) Gout ?'),
#  (617, 'What is (are) Gum (Periodontal) Disease ?'),
#  (625, 'How many people are affected by Heart Failure ?'),
#  (636, 'What causes Dry Eye ?'),
#  (647, 'What are the treatments for Gum (Periodontal) Disease ?'),
#  (673, 'What are the treatments for Heart Failure ?'),
#  (788, 'How to prevent Breast Cancer ?'),
#  (705, 'What are the treatments for Gallbladder Cancer ?'),
#  (563, 'What is (are) Heart Attack ?'),
#  (725, 'What are the treatments for Adult Acute Myeloid Leukemia ?'),
#  (727, 'What is (are) Childhood Soft Tissue Sarcoma ?'),
#  (739,
#   'What are the stages of Wilms Tumor and Other Childhood Kidney Tumors ?'),
#  (748, 'How to diagnose Wilms Tumor and Other Childhood Kidney Tumors ?'),
#  (752, 'Who is at risk for Anal Cancer? ?'),
#  (763, 'How to diagnose Childhood Extracranial Germ Cell Tumors ?'),
#  (624, 'What are the treatments for Gum (Periodontal) Disease ?'),
#  (633, 'What are the treatments for Dry Eye ?'),
#  (643, 'What is (are) Dry Eye ?'),
#  (886, 'Who is at risk for Childhood Astrocytomas? ?'),
#  (657, 'What are the treatments for Gum (Periodontal) Disease ?'),
#  (660, 'Who is at risk for Heart Failure? ?'),
#  (814, 'What are the treatments for Renal Cell Cancer ?'),
#  (816, 'What is (are) Chronic Neutrophilic Leukemia ?'),
#  (826, 'What are the symptoms of Ovarian Low Malignant Potential Tumors ?'),
#  (830, 'What are the treatments for Ovarian Low Malignant Potential Tumors ?'),
#  (690, 'What are the treatments for Hairy Cell Leukemia ?'),
#  (896,
#   'What are the symptoms of Metastatic Squamous Neck Cancer with Occult Primary ?'),
#  (856, 'What are the stages of Intraocular (Uveal) Melanoma ?'),
#  (756, 'What are the stages of Anal Cancer ?'),
#  (885, 'What causes Childhood Astrocytomas ?'),
#  (900,
#   'What are the treatments for Metastatic Squamous Neck Cancer with Occult Primary ?'),
#  (10906,
#   'How many people are affected by TK2-related mitochondrial DNA depletion syndrome, myopathic form ?'),
#  (909, 'What are the treatments for Small Intestine Cancer ?'),
#  (910,
#   'What is (are) Childhood Acute Myeloid Leukemia and Other Myeloid Malignancies ?'),
#  (923, 'How to diagnose Non-Small Cell Lung Cancer ?'),
#  (941, 'What is the outlook for Childhood Brain Stem Glioma ?'),
#  (821, 'How to diagnose Small Cell Lung Cancer ?'),
#  (973, 'How to diagnose Bile Duct Cancer (Cholangiocarcinoma) ?'),
#  (962, 'What is (are) Chronic Myelogenous Leukemia ?'),
#  (970,
#   'How to prevent Ovarian Epithelial, Fallopian Tube, and Primary Peritoneal Cancer ?'),
#  (842, 'What are the stages of Colon Cancer ?'),
#  (985, 'How to prevent Endometrial Cancer ?'),
#  (986, 'Who is at risk for Endometrial Cancer? ?'),
#  (988, 'What is (are) AIDS-Related Lymphoma ?'),
#  (868, 'What are the treatments for Hypopharyngeal Cancer ?'),
#  (1003, 'What are the stages of Bile Duct Cancer (Cholangiocarcinoma) ?'),
#  (1004, 'What are the treatments for Bile Duct Cancer (Cholangiocarcinoma) ?'),
#  (1005,
#   'What is (are) Pancreatic Neuroendocrine Tumors (Islet Cell Tumors) ?'),
#  (1015,
#   'Who is at risk for Ovarian, Fallopian Tube, and Primary Peritoneal Cancer? ?'),
#  (884, 'What is (are) Childhood Astrocytomas ?'),
#  (1038, 'What are the stages of Adult Soft Tissue Sarcoma ?'),
#  (1052, 'What are the symptoms of Gastrointestinal Carcinoid Tumors ?'),
#  (1061, 'Who is at risk for Adult Soft Tissue Sarcoma? ?'),
#  (1068, 'How to diagnose Primary CNS Lymphoma ?'),
#  (1071, 'What are the treatments for Primary CNS Lymphoma ?'),
#  (944, 'What are the treatments for Childhood Brain Stem Glioma ?'),
#  (1072, 'What are the symptoms of Nasopharyngeal Cancer ?'),
#  (953, 'What is (are) Gestational Trophoblastic Disease ?'),
#  (959, 'What are the stages of Gestational Trophoblastic Disease ?'),
#  (1097,
#   'What are the stages of Osteosarcoma and Malignant Fibrous Histiocytoma of Bone ?'),
#  (1098,
#   'What are the treatments for Osteosarcoma and Malignant Fibrous Histiocytoma of Bone ?'),
#  (980, 'How to prevent Oral Cavity and Oropharyngeal Cancer ?'),
#  (1462, 'Is Krabbe disease inherited ?'),
#  (1124, 'What are the symptoms of Chronic Lymphocytic Leukemia ?'),
#  (1126,
#   'How many people are affected by dihydrolipoamide dehydrogenase deficiency ?'),
#  (1130, 'What is (are) Adult Central Nervous System Tumors ?'),
#  (1141, 'What is (are) Essential Thrombocythemia ?'),
#  (1023, 'What are the stages of Laryngeal Cancer ?'),
#  (1024, 'What are the treatments for Laryngeal Cancer ?'),
#  (1153, 'Who is at risk for Pituitary Tumors? ?'),
#  (1155, 'How to diagnose Pituitary Tumors ?'),
#  (1159, 'What are the treatments for Pituitary Tumors ?'),
#  (1039, 'What are the stages of Salivary Gland Cancer ?'),
#  (1168, 'What are the treatments for Nasopharyngeal Cancer ?'),
#  (1049, 'What are the treatments for Childhood Non-Hodgkin Lymphoma ?'),
#  (1172, 'What are the symptoms of Gastrointestinal Stromal Tumors ?'),
#  (1173, 'What are the stages of Gastrointestinal Stromal Tumors ?'),
#  (1242, 'What is (are) Childhood Ependymoma ?'),
#  (1075, 'Who is at risk for Neuroblastoma? ?'),
#  (1243, 'What causes Childhood Ependymoma ?'),
#  (1220, 'What is the outlook for Parathyroid Cancer ?'),
#  (1223, 'What is the outlook for Childhood Craniopharyngioma ?'),
#  (1232, 'What are the treatments for Lip and Oral Cavity Cancer ?'),
#  (1129, 'What are the treatments for Chronic Lymphocytic Leukemia ?'),
#  (1235, 'Who is at risk for Prostate Cancer? ?'),
#  (1236, 'How to prevent Prostate Cancer ?'),
#  (1237, 'Who is at risk for Prostate Cancer? ?'),
#  (1240,
#   'what research (or clinical trials) is being done for Childhood Craniopharyngioma ?'),
#  (1254, 'How to diagnose Childhood Central Nervous System Germ Cell Tumors ?'),
#  (1257,
#   'What are the treatments for Childhood Central Nervous System Germ Cell Tumors ?'),
#  (1260, 'What are the symptoms of Ovarian Germ Cell Tumors ?'),
#  (1277, 'What are the stages of Childhood Hodgkin Lymphoma ?'),
#  (1268, 'How to diagnose Neuroblastoma ?'),
#  (1270, 'What are the stages of Neuroblastoma ?'),
#  (1271, 'What are the treatments for Neuroblastoma ?'),
#  (1279, 'What are the treatments for Childhood Hodgkin Lymphoma ?'),
#  (1291, 'What are the symptoms of Oropharyngeal Cancer ?'),
#  (1307, 'What are the treatments for Male Breast Cancer ?'),
#  (1316, 'What are the treatments for Urethral Cancer ?'),
#  (1393, 'How to diagnose Ewing Sarcoma ?'),
#  (1329,
#   'What are the symptoms of Childhood Central Nervous System Atypical Teratoid/Rhabdoid Tumor ?'),
#  (1334,
#   'What are the treatments for Childhood Central Nervous System Atypical Teratoid/Rhabdoid Tumor ?'),
#  (1414, 'Who is at risk for Langerhans Cell Histiocytosis? ?'),
#  (1416, 'How to diagnose Langerhans Cell Histiocytosis ?'),
#  (1356, 'What are the symptoms of Childhood Liver Cancer ?'),
#  (1359, 'What are the stages of Skin Cancer ?'),
#  (1360, 'What are the treatments for Skin Cancer ?'),
#  (14118,
#   'What are the treatments for COL4A1-related brain small-vessel disease ?'),
#  (1374, 'What are the stages of Endometrial Cancer ?'),
#  (9973, 'Is mucopolysaccharidosis type VI inherited ?'),
#  (1387, 'What are the stages of Mycosis Fungoides and the Szary Syndrome ?'),
#  (1408, 'What are the stages of Testicular Cancer ?'),
#  (1342, 'What are the stages of Retinoblastoma ?'),
#  (3259, 'How to diagnose Mantle cell lymphoma ?'),
#  (12497, 'Is citrullinemia inherited ?'),
#  (1536, 'What is (are) Bleeding Disorders ?'),
#  (4753, 'How to diagnose Klinefelter syndrome ?'),
#  (12728, 'How many people are affected by Timothy syndrome ?'),
#  (12729, 'How many people are affected by mal de Meleda ?'),
#  (1629, 'What is (are) Malnutrition ?'),
#  (1587, 'What is (are) Cirrhosis ?'),
#  (1654, 'Do you have information about Asian American Health'),
#  (13092, 'How many people are affected by glutaric acidemia type I ?'),
#  (1635, 'What are the treatments for Urinary Retention ?'),
#  (1666, 'What is (are) Eosinophilic Disorders ?'),
#  (1634, 'How to diagnose Urinary Retention ?'),
#  (1839, 'Do you have information about Inhalants'),
#  (1719, 'What are the treatments for Marden-Walker syndrome ?'),
#  (5001,
#   'What are the symptoms of Succinic semialdehyde dehydrogenase deficiency ?'),
#  (1727, 'What are the symptoms of Primary Sclerosing Cholangitis ?'),
#  (1816, 'What are the treatments for Human T-cell leukemia virus type 1 ?'),
#  (1743, 'What are the complications of Primary Sclerosing Cholangitis ?'),
#  (1748, 'What is (are) Spinal Cord Diseases ?'),
#  (1756, 'Do you have information about Water Safety (Recreational)'),
#  (1771, "What is (are) Women's Health Checkup ?"),
#  (1795, 'Do you have information about Infant and Newborn Care'),
#  (5142, 'Is Myhre syndrome inherited ?'),
#  (1842, 'What is (are) Listeria Infections ?'),
#  (1887, 'What is (are) Health Checkup ?'),
#  (1898, 'What is (are) Testicular Disorders ?'),
#  (1906, 'Do you have information about Sports Safety'),
#  (1955, 'What is (are) Lymphatic Diseases ?'),
#  (1962, 'What is (are) GERD ?'),
#  (2112, 'What is the outlook for Gerstmann-Straussler-Scheinker Disease ?'),
#  (2120,
#   'what research (or clinical trials) is being done for Gerstmann-Straussler-Scheinker Disease ?'),
#  (7194, 'How to diagnose Schimke immunoosseous dysplasia ?'),
#  (2033, 'Do you have information about Assistive Devices'),
#  (2048, 'Do you have information about Vasectomy'),
#  (2062, 'What is (are) Hair Loss ?'),
#  (2076, 'What is (are) Gallbladder Diseases ?'),
#  (2085, 'What is (are) Myositis ?'),
#  (2095, 'What is (are) Creatinine ?'),
#  (2097, 'What is (are) Chest Injuries and Disorders ?'),
#  (2152, 'Do you have information about Tears'),
#  (2164, 'Do you have information about Skin Aging'),
#  (13723, 'Is prekallikrein deficiency inherited ?'),
#  (2195, 'Do you have information about Triglycerides'),
#  (2210, 'What is (are) Sore Throat ?'),
#  (2234, 'What is (are) Vulvar Disorders ?'),
#  (2236, 'Do you have information about Toddler Nutrition'),
#  (2247, 'What is (are) Cellulitis ?'),
#  (10044, 'How many people are affected by mycosis fungoides ?'),
#  (2276, 'What is (are) Gay, Lesbian, Bisexual and Transgender Health ?'),
#  (2290, 'What is (are) Obesity in Children ?'),
#  (7535, 'Is Multifocal motor neuropathy inherited ?'),
#  (2315, 'What are the symptoms of Neonatal progeroid syndrome ?'),
#  (9112, 'What is the outlook for Inflammatory Myopathies ?'),
#  (2329, 'Do you have information about Anatomy'),
#  (2333, 'What is (are) Child Abuse ?'),
#  (2342, 'What is the outlook for Primary Lateral Sclerosis ?'),
#  (2365, "Do you have information about Teens' Page"),
#  (2373, 'Do you have information about Baby Health Checkup'),
#  (2402,
#   'what research (or clinical trials) is being done for Neurodegeneration with Brain Iron Accumulation ?'),
#  (2407, 'What is (are) Abortion ?'),
#  (2489, 'What are the symptoms of Blue rubber bleb nevus syndrome ?'),
#  (2484,
#   'What are the symptoms of Mental retardation Smith Fineman Myers type ?'),
#  (2448, 'What is (are) Palmoplantar keratoderma ?'),
#  (2465, 'What are the symptoms of Hereditary hemorrhagic telangiectasia ?'),
#  (2467, 'What are the treatments for Chorea-acanthocytosis ?'),
#  (2491, 'What are the treatments for Blue rubber bleb nevus syndrome ?'),
#  (2541, "What are the symptoms of Bell's palsy ?"),
#  (2513, 'What are the symptoms of CHILD syndrome ?'),
#  (2556, 'What is (are) Syndactyly type 3 ?'),
#  (11519, 'Is FOXG1 syndrome inherited ?'),
#  (2570, 'What is (are) Eisenmenger syndrome ?'),
#  (2629, 'What are the symptoms of Type 1 plasminogen deficiency ?'),
#  (2578, 'What is (are) Collagenous colitis ?'),
#  (2584, 'What is (are) L1 syndrome ?'),
#  (2610, 'What is (are) Periventricular heterotopia ?'),
#  (2620, 'What are the symptoms of Gordon syndrome ?'),
#  (2676, 'What are the symptoms of Anophthalmia plus syndrome ?'),
#  (2630, 'What causes Type 1 plasminogen deficiency ?'),
#  (2637, 'What are the symptoms of VACTERL association ?'),
#   'What is (are) Parasites - Enterobiasis (also known as Pinworm Infection) ?'),
#  (8456, 'How to diagnose Pulmonary Embolism ?'),
#  (8457, 'What are the treatments for Pulmonary Embolism ?'),
#  (7953,
#   'How to prevent Parasites - Angiostrongyliasis (also known as Angiostrongylus Infection) ?'),
#  (7963,
#   'What are the treatments for Parasites - Cyclosporiasis (Cyclospora Infection) ?'),
#  (8009,
#   'How to diagnose Parasites - Trichinellosis (also known as Trichinosis) ?'),
#  (8018,
#   'How to prevent Acanthamoeba - Granulomatous Amebic Encephalitis (GAE); Keratitis ?'),
#  (8023,
#   'What is (are) Parasites - Trichuriasis (also known as Whipworm Infection) ?'),
#  (8025,
#   'How to diagnose Parasites - Trichuriasis (also known as Whipworm Infection) ?'),
#  (8554, 'What are the treatments for High Blood Cholesterol ?'),
#  (8041,
#   'What is (are) Parasites - African Trypanosomiasis (also known as Sleeping Sickness) ?'),
#  (8042,
#   'Who is at risk for Parasites - African Trypanosomiasis (also known as Sleeping Sickness)? ?'),
#  (8562, 'What is (are) Heart Valve Disease ?'),
#  (8045, 'How to prevent Kyasanur Forest Disease (KFD) ?'),
#  (8587, 'What are the treatments for Carotid Artery Disease ?'),
#  (8590, 'What causes Sudden Cardiac Arrest ?'),
#  (8073, 'What are the treatments for Kyasanur Forest Disease (KFD) ?'),
#  (8084,
#   'What is (are) Parasites - Paragonimiasis (also known as Paragonimus Infection) ?'),
#  (8609, 'What is (are) Asbestos-Related Lung Diseases ?'),
#  (8093,
#   'What are the treatments for Marburg hemorrhagic fever (Marburg HF) ?'),
#  (8613, 'How to diagnose Asbestos-Related Lung Diseases ?'),
#  (8097, 'How to diagnose Parasites - Lymphatic Filariasis ?'),
#  (8114, 'What are the treatments for Parasites - Schistosomiasis ?'),
#  (8118, 'what is staphylococcus aureus?'),
#  (8123, 'How to prevent  ?'),
#  (8651, 'How to diagnose Tetralogy of Fallot ?'),
#  (8125, 'Who is at risk for Nocardiosis? ?'),
#  (8133, 'What are the treatments for Parasites - Lice - Head Lice ?'),
#  (8655, 'What causes Heart Murmur ?'),
#  (8657, 'How to diagnose Heart Murmur ?'),
#  (8144, 'How to diagnose Parasites - Hookworm ?'),
#  (8160,
#   'Who is at risk for Parasites - Toxoplasmosis (Toxoplasma infection)? ?'),
#  (8165, 'What is (are) Acinetobacter in Healthcare Settings ?'),
#  (8180, 'How to prevent Sickle Cell Disease ?'),
#  (8698, 'What causes Cardiogenic Shock ?'),
#  (8187, 'What causes Immune Thrombocytopenia ?'),
#  (8191, 'What are the treatments for Immune Thrombocytopenia ?'),
#  (8195, 'How to prevent Hemochromatosis ?'),
#  (8722, 'How to diagnose Von Willebrand Disease ?'),
#  (8744, 'What are the treatments for Respiratory Distress Syndrome ?'),
#  (8230, 'What are the symptoms of Fanconi Anemia ?'),
#  (8237, 'What are the treatments for Holes in the Heart ?'),
#  (8240, 'How to diagnose Fanconi Anemia ?'),
#  (8748, 'How to diagnose Obesity Hypoventilation Syndrome ?'),
#  (8749, 'What are the treatments for Obesity Hypoventilation Syndrome ?'),
#  (8959,
#   'what research (or clinical trials) is being done for Attention Deficit-Hyperactivity Disorder ?'),
#  (8762, 'What are the treatments for Myotonia ?'),
#  (8251, 'What causes Mitral Valve Prolapse ?'),
#  (8260, 'What are the treatments for Cough ?'),
#  (8771, 'What is the outlook for Arachnoid Cysts ?'),
#  (8271, 'What is (are) Aplastic Anemia ?'),
#  (8276, 'What are the treatments for Aplastic Anemia ?'),
#  (8286, 'Is arrhythmogenic right ventricular cardiomyopathy inherited ?'),
#  (8822, 'What is the outlook for Kleine-Levin Syndrome ?'),
#  (8293, 'What are the treatments for Heart Attack ?'),
#  (8299, 'How to diagnose Coronary Microvascular Disease ?'),
#  (8302, 'What is (are) Sleep Deprivation and Deficiency ?'),
#  (8850, 'What are the treatments for Sotos Syndrome ?'),
#  (4684, 'What is (are) Isodicentric chromosome 15 syndrome ?'),
#  (8316, 'What are the treatments for ARDS ?'),
#  (8325, 'What causes Bronchitis ?'),
#  (8333, 'Who is at risk for Broken Heart Syndrome? ?'),
#  (14745, 'What is (are) hypermethioninemia ?'),
#  (8356, 'What are the treatments for Polycythemia Vera ?'),
#  (8357, 'How to prevent Polycythemia Vera ?'),
#  (8358, 'What is (are) Childhood Interstitial Lung Disease ?'),
#  (8361, 'Who is at risk for Childhood Interstitial Lung Disease? ?'),
#  (14746, 'How many people are affected by hypermethioninemia ?'),
#  (8386, 'What are the treatments for Peripheral Artery Disease ?'),
#  (8387, 'What are the treatments for Microcephaly ?'),
#  (8388, 'How to prevent Peripheral Artery Disease ?'),
#  (8394, 'How to diagnose Angina ?'),
#  (8418, 'What causes Coronary Heart Disease ?'),
#  (8427, 'What are the treatments for Atherosclerosis ?'),
#  (8431, 'Who is at risk for Sickle Cell Disease? ?'),
#  (8436, 'Who is at risk for Coronary Heart Disease? ?'),
#  (8437, 'What are the symptoms of Coronary Heart Disease ?'),
#  (8439, 'What causes Alpha-1 Antitrypsin Deficiency ?'),
#  (8493, 'What causes Kawasaki Disease ?'),
#  (8494, 'Who is at risk for Kawasaki Disease? ?'),
#  (8444, 'How to diagnose Coronary Heart Disease ?'),
#  (8449, 'What are the symptoms of Primary Ciliary Dyskinesia ?'),
#  (8450, 'How to diagnose Primary Ciliary Dyskinesia ?'),
#  (8459, 'What is (are) Sleep Apnea ?'),
#  (8463, 'How to diagnose Sleep Apnea ?'),
#  (9104, 'What is the outlook for Dysgraphia ?'),
#  (9119, "What are the treatments for Todd's Paralysis ?"),
#  (8479, 'What are the symptoms of Restless Legs Syndrome ?'),
#  (8480, 'What are the treatments for Hemophilia ?'),
#  (8483, 'What are the treatments for Restless Legs Syndrome ?'),
#  (8505, 'What are the treatments for Metabolic Syndrome ?'),
#  (9135, 'What is the outlook for Fibromuscular Dysplasia ?'),
#  (8497, 'What are the treatments for Kawasaki Disease ?'),
#  (8525, 'What causes Diabetic Heart Disease ?'),
#  (8526, 'Who is at risk for Diabetic Heart Disease? ?'),
#  (8510, 'Who is at risk for Asthma? ?'),
#  (8513, 'What are the treatments for Asthma ?'),
#  (9166, 'What is the outlook for Hypotonia ?'),
#  (8519, 'Who is at risk for Stroke? ?'),
#  (8521, 'How to diagnose Stroke ?'),
#  (8537, 'What are the treatments for Bronchopulmonary Dysplasia ?'),
#  (14755,
#   'What are the genetic changes related to argininosuccinic aciduria ?'),
#  (9193, 'What is the outlook for Pinched Nerve ?'),
#  (9227, 'What are the treatments for Alexander Disease ?'),
#  (14756, 'Is argininosuccinic aciduria inherited ?'),
#  (9264, 'What are the treatments for Agnosia ?'),
#  (9017, 'What are the treatments for Klver-Bucy Syndrome ?'),
#  (9268, 'What is the outlook for Dermatomyositis ?'),
#  (8592, 'What are the symptoms of Sudden Cardiac Arrest ?'),
#  (8594, 'What are the treatments for Sudden Cardiac Arrest ?'),
#  (8595, 'How to prevent Sudden Cardiac Arrest ?'),
#  (14757, 'What are the treatments for argininosuccinic aciduria ?'),
#  (9300, 'What are the treatments for Hydromyelia ?'),
#  (8620, 'How to diagnose Idiopathic Pulmonary Fibrosis ?'),
#  (8621, 'What are the treatments for Idiopathic Pulmonary Fibrosis ?'),
#  (8623, 'What causes Overweight and Obesity ?'),
#  (8627, 'How to diagnose Overweight and Obesity ?'),
#  (8628, 'What are the treatments for Overweight and Obesity ?'),
#  (9338, "What is the outlook for Isaacs' Syndrome ?"),
#  (8635, 'Who is at risk for Marfan Syndrome? ?'),
#  (8648, 'What is (are) Tetralogy of Fallot ?'),
#  (8653, 'How to prevent Heart Palpitations ?'),
#  (9351, "What are the treatments for Fahr's Syndrome ?"),
#  (8665, 'How to diagnose Heart Palpitations ?'),
#  (8681,
#   "what research (or clinical trials) is being done for Cushing's Syndrome ?"),
#  (8686, 'How to diagnose Hemolytic Anemia ?'),
#  (9418, 'What is the outlook for Tay-Sachs Disease ?'),
#  (8772,
#   'what research (or clinical trials) is being done for Arachnoid Cysts ?'),
#  (8719, 'What causes Von Willebrand Disease ?'),
#  (8730, 'How to prevent Rh Incompatibility ?'),
#  (8732, 'What is (are) Sarcoidosis ?'),
#  (8735, 'What are the symptoms of Sarcoidosis ?'),
#  (8750, 'How to prevent Obesity Hypoventilation Syndrome ?'),
#  (9500, 'What is the outlook for Troyer Syndrome ?'),
#  (8754, 'What are the symptoms of Cardiomyopathy ?'),
#  (8767, 'What is the outlook for Locked-In Syndrome ?'),
#  (8775, 'What is the outlook for Congenital Myasthenia ?'),
#  (9524, 'What is the outlook for Brown-Sequard Syndrome ?'),
#  (8789, 'What is the outlook for Essential Tremor ?'),
#  (8803, 'What is the outlook for Narcolepsy ?'),
#  (8806,
#   'What are the treatments for Gerstmann-Straussler-Scheinker Disease ?'),
#  (12767,
#   'How many people are affected by dihydropyrimidine dehydrogenase deficiency ?'),
#  (8875, 'What are the treatments for Craniosynostosis ?'),
#  (8876, 'What is the outlook for Craniosynostosis ?'),
#  (8880, 'What are the treatments for Miller Fisher Syndrome ?'),
#  (8901, 'What is the outlook for Paroxysmal Choreoathetosis ?'),
#  (9652,
#   'What is the outlook for Cerebro-Oculo-Facio-Skeletal Syndrome (COFS) ?'),
#  (8963, 'What is the outlook for Klver-Bucy Syndrome ?'),
#  (8964,
#   'what research (or clinical trials) is being done for Klver-Bucy Syndrome ?'),
#  (9696, 'What is the outlook for Paroxysmal Hemicrania ?'),
#  (9732, 'What is the outlook for Colpocephaly ?'),
#  (9014, 'What is the outlook for Tuberous Sclerosis ?'),
#  (9757, 'What is the outlook for Tarlov Cysts ?'),
#  (9045,
#   'what research (or clinical trials) is being done for Normal Pressure Hydrocephalus ?'),
#  (9089, 'What is the outlook for Barth Syndrome ?'),
#  (9803, 'How many people are affected by pachyonychia congenita ?'),
#  (9120, "What is the outlook for Todd's Paralysis ?"),
#  (9139, 'What is the outlook for Ataxia ?'),
#  (9152, 'What is the outlook for Zellweger Syndrome ?'),
#  (9160, "What is the outlook for Bell's Palsy ?"),
#  (9879, 'How many people are affected by methylmalonic acidemia ?'),
#  (9172, 'What is (are) Aicardi-Goutieres Syndrome Disorder ?'),
#  (9180, 'What is (are) Absence of the Septum Pellucidum ?'),
#  (9197, 'What is the outlook for Leukodystrophy ?'),
#  (9214, 'What is the outlook for Tremor ?'),
#  (9217, 'What are the treatments for Alternating Hemiplegia ?'),
#  (9228, 'What is the outlook for Alexander Disease ?'),
#  (9266, 'what research (or clinical trials) is being done for Agnosia ?'),
#  (9301, 'What is the outlook for Hydromyelia ?'),
#  (9302, 'what research (or clinical trials) is being done for Hydromyelia ?'),
#  (9313, 'What is the outlook for Repetitive Motion Disorders ?'),
#  (9329, 'What are the treatments for Apraxia ?'),
#  (9346, 'What are the treatments for Sleep Apnea ?'),
#  (9359, 'What are the treatments for Sydenham Chorea ?'),
#  (9360, 'How many people are affected by arterial tortuosity syndrome ?'),
#  (9372, 'What are the treatments for Machado-Joseph Disease ?'),
#  (10059, 'How many people are affected by proopiomelanocortin deficiency ?'),
#  (10087, 'How many people are affected by deoxyguanosine kinase deficiency ?'),
#  (9423, 'What are the treatments for Klippel Feil Syndrome ?'),
#  (9435, 'What are the treatments for Melkersson-Rosenthal Syndrome ?'),
#  (9437,
#   'what research (or clinical trials) is being done for Melkersson-Rosenthal Syndrome ?'),
#  (9447, 'What are the treatments for Wernicke-Korsakoff Syndrome ?'),
#  (9458,
#   'what research (or clinical trials) is being done for Hydrocephalus ?'),
#  (10141, 'How many people are affected by Weaver syndrome ?'),
#  (9497,
#   'what research (or clinical trials) is being done for Asperger Syndrome ?'),
#  (9541,
#   'what research (or clinical trials) is being done for Aicardi Syndrome ?'),
#  (9544, 'What are the treatments for Holoprosencephaly ?'),
#  (9545, 'What is the outlook for Holoprosencephaly ?'),
#  (9559, 'What is the outlook for Neurosarcoidosis ?'),
#  (10242, 'How many people are affected by complete LCAT deficiency ?'),
#  (9589, 'What is the outlook for Mucolipidoses ?'),
#  (10277, 'How many people are affected by ataxia with vitamin E deficiency ?'),
#  (10289, 'Is Wagner syndrome inherited ?'),
#  (10297, 'How many people are affected by Roberts syndrome ?'),
#  (10326, 'Is Manitoba oculotrichoanal syndrome inherited ?'),
#  (9660, 'What are the treatments for Prosopagnosia ?'),
#  (9695, 'What are the treatments for Paroxysmal Hemicrania ?'),
#  (10372, 'How many people are affected by Lujan syndrome ?'),
#  (10377, 'How many people are affected by Amish lethal microcephaly ?'),
#  (9707, 'What are the treatments for Cerebellar Hypoplasia ?'),
#  (10387,
#   'How many people are affected by arrhythmogenic right ventricular cardiomyopathy ?'),
#  (9888,
#   'What are the treatments for dilated cardiomyopathy with ataxia syndrome ?'),
#  (9793, 'How many people are affected by Rabson-Mendenhall syndrome ?'),
#  (10490, 'How many people are affected by Melnick-Needles syndrome ?'),
#  (9824, 'Is infantile-onset spinocerebellar ataxia inherited ?'),
#  (9827,
#   'How many people are affected by succinyl-CoA:3-ketoacid CoA transferase deficiency ?'),
#  (9853,
#   'How many people are affected by Hutchinson-Gilford progeria syndrome ?'),
#  (10546, 'How many people are affected by cherubism ?'),
#  (9861, 'Is Northern epilepsy inherited ?'),
#  (10560, 'How many people are affected by GRACILE syndrome ?'),
#  (9876, 'Is Silver syndrome inherited ?'),
#  (10579,
#   'How many people are affected by X-linked lissencephaly with abnormal genitalia ?'),
#  (10597,
#   'How many people are affected by esophageal atresia/tracheoesophageal fistula ?'),
#  (10607, 'How many people are affected by Crouzon syndrome ?'),
#  (10623, 'How many people are affected by polymicrogyria ?'),
#  (9939, 'What are the treatments for complement factor I deficiency ?'),
#  (10641, 'How many people are affected by Rett syndrome ?'),
#  (10649, 'How many people are affected by aspartylglucosaminuria ?'),
#  (9969, 'Is chronic atrial and intestinal dysrhythmia inherited ?'),
#  (9978, 'Is familial osteochondritis dissecans inherited ?'),
#  (10004, 'Is Pallister-Killian mosaic syndrome inherited ?'),
#  (10016, 'What are the treatments for atopic dermatitis ?'),
#  (10046, 'Is mycosis fungoides inherited ?'),
#  (10048, 'What is (are) essential pentosuria ?'),
#  (10747, 'How many people are affected by Renpenning syndrome ?'),
#  (10055, 'Is familial hypobetalipoproteinemia inherited ?'),
#  (10064,
#   'How many people are affected by fragile X-associated tremor/ataxia syndrome ?'),
#  (10079,
#   'What are the genetic changes related to infantile neuronal ceroid lipofuscinosis ?'),
#  (10088,
#   'What are the genetic changes related to deoxyguanosine kinase deficiency ?'),
#  (10109, 'What are the treatments for Koolen-de Vries syndrome ?'),
#  (10824, 'Is bladder cancer inherited ?'),
#  (10189, 'How many people are affected by juvenile hyaline fibromatosis ?'),
#  (10355, 'Is osteoglophonic dysplasia inherited ?'),
#  (10154, 'What are the treatments for psoriatic arthritis ?'),
#  (10865,
#   'How many people are affected by hereditary diffuse gastric cancer ?'),
#  (10161, 'Is congenital diaphragmatic hernia inherited ?'),
#  (10871,
#   'How many people are affected by X-linked infantile spasm syndrome ?'),
#  ...]

# %%
import psycopg2
import numpy as np

# Connexion PostgreSQL
conn = psycopg2.connect(
    dbname=DB_NAME,
    user=DB_USER,
    password=DB_PASSWORD,
    host=DB_HOST,
    port=DB_PORT
)
cursor = conn.cursor()

# Paramètres
BATCH_SIZE = 50  # Taille du batch pour optimiser les requêtes
USE_HF_FALLBACK = True  # Activer le fallback immédiat vers Hugging Face

# Récupérer toutes les questions sans embeddings
cursor.execute("SELECT id, question FROM ae_qa_table WHERE embedding IS NULL")
questions = cursor.fetchall()

if not questions:
    print("✅ Toutes les questions ont déjà des embeddings.")
else:
    print(f"🔄 Chargement de {len(questions)} questions à traiter...")

    for i in range(0, len(questions), BATCH_SIZE):
        batch = questions[i : i + BATCH_SIZE]
        batch_ids = [q[0] for q in batch]
        batch_questions = [q[1] for q in batch]

        try:
            # Essayer d'obtenir les embeddings via Vertex AI
            embedding_vectors = [hf_model.encode(q).tolist() for q in batch_questions]
        except Exception as e:
            if "429 Quota exceeded" in str(e) or "Retrying vertexai" in str(e):
                print(f"⚠️ Vertex AI dépasse le quota ! Passage immédiat à Hugging Face pour le batch {i // BATCH_SIZE + 1}.")
                embedding_vectors = [hf_model.encode(q).tolist() for q in batch_questions] 
            else:
                print(f"❌ Erreur inattendue avec Vertex AI : {e}")
                continue  # Passer au batch suivant

        # Stockage dans PostgreSQL en batch
        update_values = [(embedding_vectors[idx], batch_ids[idx]) for idx in range(len(batch))]
        cursor.executemany("UPDATE ae_qa_table SET embedding = %s WHERE id = %s", update_values)
        conn.commit()

        print(f"✅ Batch {i // BATCH_SIZE + 1} / {len(questions) // BATCH_SIZE + 1} traité.")

    print("🎯 Tous les embeddings ont été stockés.")

cursor.close()
conn.close()
print("🔚 Connexion PostgreSQL fermée.")
# Out:
# 🔄 Chargement de 16412 questions à traiter...
# ✅ Batch 1 / 329 traité.
# ✅ Batch 2 / 329 traité.
# ✅ Batch 3 / 329 traité.
# ✅ Batch 4 / 329 traité.
# ✅ Batch 5 / 329 traité.
# ✅ Batch 6 / 329 traité.
# ✅ Batch 7 / 329 traité.
# ✅ Batch 8 / 329 traité.
# ✅ Batch 9 / 329 traité.
# ✅ Batch 10 / 329 traité.
# ✅ Batch 11 / 329 traité.
# ✅ Batch 12 / 329 traité.
# ✅ Batch 13 / 329 traité.
# ✅ Batch 14 / 329 traité.
# ✅ Batch 15 / 329 traité.
# ✅ Batch 16 / 329 traité.
# ✅ Batch 17 / 329 traité.
# ✅ Batch 18 / 329 traité.
# ✅ Batch 19 / 329 traité.
# ✅ Batch 20 / 329 traité.
# ✅ Batch 21 / 329 traité.
# ✅ Batch 22 / 329 traité.
# ✅ Batch 23 / 329 traité.
# ✅ Batch 24 / 329 traité.
# ✅ Batch 25 / 329 traité.
# ✅ Batch 26 / 329 traité.
# ✅ Batch 27 / 329 traité.
# ✅ Batch 28 / 329 traité.
# ✅ Batch 29 / 329 traité.
# ✅ Batch 30 / 329 traité.
# ✅ Batch 31 / 329 traité.
# ✅ Batch 32 / 329 traité.
# ✅ Batch 33 / 329 traité.
# ✅ Batch 34 / 329 traité.
# ✅ Batch 35 / 329 traité.
# ✅ Batch 36 / 329 traité.
# ✅ Batch 37 / 329 traité.
# ✅ Batch 38 / 329 traité.
# ✅ Batch 39 / 329 traité.
# ✅ Batch 40 / 329 traité.
# ✅ Batch 41 / 329 traité.
# ✅ Batch 42 / 329 traité.
# ✅ Batch 43 / 329 traité.
# ✅ Batch 44 / 329 traité.
# ✅ Batch 45 / 329 traité.
# ✅ Batch 46 / 329 traité.
# ✅ Batch 47 / 329 traité.
# ✅ Batch 48 / 329 traité.
# ✅ Batch 49 / 329 traité.
# ✅ Batch 297 / 329 traité.
# ✅ Batch 298 / 329 traité.
# ✅ Batch 299 / 329 traité.
# ✅ Batch 300 / 329 traité.
# ✅ Batch 301 / 329 traité.
# ✅ Batch 302 / 329 traité.
# ✅ Batch 303 / 329 traité.
# ✅ Batch 304 / 329 traité.
# ✅ Batch 305 / 329 traité.
# ✅ Batch 306 / 329 traité.
# ✅ Batch 307 / 329 traité.
# ✅ Batch 308 / 329 traité.
# ✅ Batch 309 / 329 traité.
# ✅ Batch 310 / 329 traité.
# ✅ Batch 311 / 329 traité.
# ✅ Batch 312 / 329 traité.
# ✅ Batch 313 / 329 traité.
# ✅ Batch 314 / 329 traité.
# ✅ Batch 315 / 329 traité.
# ✅ Batch 316 / 329 traité.
# ✅ Batch 317 / 329 traité.
# ✅ Batch 318 / 329 traité.
# ✅ Batch 319 / 329 traité.
# ✅ Batch 320 / 329 traité.
# ✅ Batch 321 / 329 traité.
# ✅ Batch 322 / 329 traité.
# ✅ Batch 323 / 329 traité.
# ✅ Batch 324 / 329 traité.
# ✅ Batch 325 / 329 traité.
# ✅ Batch 326 / 329 traité.
# ✅ Batch 327 / 329 traité.
# ✅ Batch 328 / 329 traité.
# ✅ Batch 329 / 329 traité.
# 🎯 Tous les embeddings ont été stockés.
# 🔚 Connexion PostgreSQL fermée.

# %%
import psycopg2
import numpy as np

# Connexion PostgreSQL
conn = psycopg2.connect(
    dbname=DB_NAME,
    user=DB_USER,
    password=DB_PASSWORD,
    host=DB_HOST,
    port=DB_PORT
)
cursor = conn.cursor()

# Paramètres
BATCH_SIZE = 50  # Taille du batch pour optimiser les requêtes
USE_HF_FALLBACK = True  # Activer le fallback immédiat vers Hugging Face

# Récupérer toutes les questions sans embeddings
cursor.execute("SELECT drug FROM ae_med_table WHERE embedding IS NULL")
questions = cursor.fetchall()

if not questions:
    print("✅ Toutes les drugs ont déjà des embeddings.")
else:
    print(f"🔄 Chargement de {len(questions)} drug à traiter...")

    for i in range(0, len(questions), BATCH_SIZE):
        batch = questions[i : i + BATCH_SIZE]
        batch_ids = [q[0] for q in batch]
        batch_questions = [q[1] for q in batch]

        try:
            # Essayer d'obtenir les embeddings via Vertex AI
            embedding_vectors = [hf_model.encode(q).tolist() for q in batch_questions]
        except Exception as e:
            if "429 Quota exceeded" in str(e) or "Retrying vertexai" in str(e):
                print(f"⚠️ Vertex AI dépasse le quota ! Passage immédiat à Hugging Face pour le batch {i // BATCH_SIZE + 1}.")
                embedding_vectors = [hf_model.encode(q).tolist() for q in batch_questions] 
            else:
                print(f"❌ Erreur inattendue avec Vertex AI : {e}")
                continue  # Passer au batch suivant

        # Stockage dans PostgreSQL en batch
        update_values = [(embedding_vectors[idx], batch_ids[idx]) for idx in range(len(batch))]
        cursor.executemany("UPDATE ae_med_table SET embedding = %s WHERE id = %s", update_values)
        conn.commit()

        print(f"✅ Batch {i // BATCH_SIZE + 1} / {len(questions) // BATCH_SIZE + 1} traité.")

    print("🎯 Tous les embeddings ont été stockés.")

cursor.close()
conn.close()
print("🔚 Connexion PostgreSQL fermée.")
